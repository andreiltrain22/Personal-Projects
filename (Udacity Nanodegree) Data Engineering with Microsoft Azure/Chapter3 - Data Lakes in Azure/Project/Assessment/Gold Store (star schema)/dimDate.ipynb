r><tr><td>2021-02-01</td></tr><tr><td>2021-03-01</td></tr><tr><td>2021-04-01</td></tr><tr><td>2021-05-01</td></tr><tr><td>2021-06-01</td></tr><tr><td>2021-07-01</td></tr><tr><td>2021-08-01</td></tr><tr><td>2021-09-01</td></tr><tr><td>2021-10-01</td></tr><tr><td>2021-11-01</td></tr><tr><td>2021-12-01</td></tr><tr><td>2022-01-01</td></tr><tr><td>2022-02-01</td></tr><tr><td>2020-04-01</td></tr><tr><td>2020-05-01</td></tr><tr><td>2020-06-01</td></tr><tr><td>2020-07-01</td></tr><tr><td>2020-08-01</td></tr><tr><td>2020-09-01</td></tr><tr><td>2020-10-01</td></tr><tr><td>2020-11-01</td></tr><tr><td>2020-12-01</td></tr><tr><td>2021-01-01</td></tr><tr><td>2021-02-01</td></tr><tr><td>2021-03-01</td></tr><tr><td>2021-04-01</td></tr><tr><td>2021-05-01</td></tr><tr><td>2021-06-01</td></tr><tr><td>2021-07-01</td></tr><tr><td>2021-08-01</td></tr><tr><td>2021-09-01</td></tr><tr><td>2021-10-01</td></tr><tr><td>2021-11-01</td></tr><tr><td>2021-12-01</td></tr><tr><td>2022-01-01</td></tr><tr><td>2022-02-01</td></tr><tr><td>2020-12-01</td></tr><tr><td>2021-01-01</td></tr><tr><td>2021-02-01</td></tr><tr><td>2021-03-01</td></tr><tr><td>2021-04-01</td></tr><tr><td>2021-05-01</td></tr><tr><td>2021-06-01</td></tr><tr><td>2021-07-01</td></tr><tr><td>2021-08-01</td></tr><tr><td>2021-09-01</td></tr><tr><td>2021-10-01</td></tr><tr><td>2021-11- ...

# %%
payment_dt_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- date: date (nullable = true)
#
# </div>

# %%
# Calculate minimum payment date
min_dt = (
    payment_dt_df
        .select(min(col("date")))
        .first()
        [0]
)

print(type(min_dt))
print(min_dt)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;datetime.date&#39;&gt;
# 2013-02-01
# </div>

# %%
# Calculate maximum payment date
max_dt = (
    payment_dt_df
        .select(max(col("date")))
        .first()
        [0]
)

print(type(max_dt))
print(max_dt)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;datetime.date&#39;&gt;
# 2022-02-01
# </div>

# %%
# Generate continuous range (list) of dates (interval = 1 day between subsequent dates) between min payment date and 10 years in the future from max payment date

from datetime import timedelta

calendar_list = []
dt = min_dt

while dt <= max_dt + timedelta(days = 365 * 10):
    calendar_list.append(dt)
    dt+=timedelta(days = 1)

print(calendar_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[datetime.date(2013, 2, 1), datetime.date(2013, 2, 2), datetime.date(2013, 2, 3), datetime.date(2013, 2, 4), datetime.date(2013, 2, 5), datetime.date(2013, 2, 6), datetime.date(2013, 2, 7), datetime.date(2013, 2, 8), datetime.date(2013, 2, 9), datetime.date(2013, 2, 10), datetime.date(2013, 2, 11), datetime.date(2013, 2, 12), datetime.date(2013, 2, 13), datetime.date(2013, 2, 14), datetime.date(2013, 2, 15), datetime.date(2013, 2, 16), datetime.date(2013, 2, 17), datetime.date(2013, 2, 18), datetime.date(2013, 2, 19), datetime.date(2013, 2, 20), datetime.date(2013, 2, 21), datetime.date(2013, 2, 22), datetime.date(2013, 2, 23), datetime.date(2013, 2, 24), datetime.date(2013, 2, 25), datetime.date(2013, 2, 26), datetime.date(2013, 2, 27), datetime.date(2013, 2, 28), datetime.date(2013, 3, 1), datetime.date(2013, 3, 2), datetime.date(2013, 3, 3), datetime.date(2013, 3, 4), datetime.date(2013, 3, 5), datetime.date(2013, 3, 6), datetime.date(2013, 3, 7), datetime.date(2013, 3, 8), datetime.date(2013, 3, 9), datetime.date(2013, 3, 10), datetime.date(2013, 3, 11), datetime.date(2013, 3, 12), datetime.date(2013, 3, 13), datetime.date(2013, 3, 14), datetime.date(2013, 3, 15), datetime.date(2013, 3, 16), datetime.date(2013, 3, 17), datetime.date(2013, 3, 18), datetime.date(2013, 3, 19), datetime.date(2013, 3, 20), datetime.date(2013, 3, 21), datetime.date(2013, 3, 22), datetime.date(2013, 3, 23), datetime.date(2013, 3, 24), datetime.date(2013, 3, 25), datetime.date(2013, 3, 26), datetime.date(2013, 3, 27), datetime.date(2013, 3, 28), datetime.date(2013, 3, 29), datetime.date(2013, 3, 30), datetime.date(2013, 3, 31), datetime.date(2013, 4, 1), datetime.date(2013, 4, 2), datetime.date(2013, 4, 3), datetime.date(2013, 4, 4), datetime.date(2013, 4, 5), datetime.date(2013, 4, 6), datetime.date(2013, 4, 7), datetime.date(2013, 4, 8), datetime.date(2013, 4, 9), datetime.date(2013, 4, 10), datetime.date(2013, 4, 11), datetime.date(2013, 4, 12), datetime.date(2013, 4, 13), datetime.date(2013, 4, 14), datetime.date(2013, 4, 15), datetime.date(2013, 4, 16), datetime.date(2013, 4, 17), datetime.date(2013, 4, 18), datetime.date(2013, 4, 19), datetime.date(2013, 4, 20), datetime.date(2013, 4, 21), datetime.date(2013, 4, 22), datetime.date(2013, 4, 23), datetime.date(2013, 4, 24), datetime.date(2013, 4, 25), datetime.date(2013, 4, 26), datetime.date(2013, 4, 27), datetime.date(2013, 4, 28), datetime.date(2013, 4, 29), datetime.date(2013, 4, 30), datetime.date(2013, 5, 1), datetime.date(2013, 5, 2), datetime.date(2013, 5, 3), datetime.date(2013, 5, 4), datetime.date(2013, 5, 5), datetime.date(2013, 5, 6), datetime.date(2013, 5, 7), datetime.date(2013, 5, 8), datetime.date(2013, 5, 9), datetime.date(2013, 5, 10), datetime.date(2013, 5, 11), datetime.date(2013, 5, 12), datetime.date(2013, 5, 13), datetime.date(2013, 5, 14), datetime.date(2013, 5, 15), datetime.date(2013, 5, 16), datetime.date(2013, 5, 17), datetime.date(2013, 5, 18), datetime.date(2013, 5, 19), datetime.date(2013, 5, 20), datetime.date(2013, 5, 21), datetime.date(2013, 5, 22), datetime.date(2013, 5, 23), datetime.date(2013, 5, 24), datetime.date(2013, 5, 25), datetime.date(2013, 5, 26), datetime.date(2013, 5, 27), datetime.date(2013, 5, 28), datetime.date(2013, 5, 29), datetime.date(2013, 5, 30), datetime.date(2013, 5, 31), datetime.date(2013, 6, 1), datetime.date(2013, 6, 2), datetime.date(2013, 6, 3), datetime.date(2013, 6, 4), datetime.date(2013, 6, 5), datetime.date(2013, 6, 6), datetime.date(2013, 6, 7), datetime.date(2013, 6, 8), datetime.date(2013, 6, 9), datetime.date(2013, 6, 10), datetime.date(2013, 6, 11), datetime.date(2013, 6, 12), datetime.date(2013, 6, 13), datetime.date(2013, 6, 14), datetime.date(2013, 6, 15), datetime.date(2013, 6, 16), datetime.date(2013, 6, 17), datetime.date(2013, 6, 18), datetime.date(2013, 6, 19), datetime.date(2013, 6, 20), datetime.date(2013, 6, 21), datetime.date(2013, 6, 22), datetime.date(2013, 6, 23), datetime.date(2013, ...

# %%
# Convert the list of dates generated earlier to calendar dataframe by extending the date column to multiple required attributes: month, year, day of week, etc.
from pyspark.sql.types import DateType

calendar_df = (
    spark
        .createDataFrame(calendar_list, DateType())
        .withColumnRenamed("value", "date_value")
        .select(
            (
             year(col("date_value")) * 10000 + 
             month(col("date_value")) * 100 + 
             dayofmonth(col("date_value"))
            ).alias("date_id"),
            col("date_value"),
            month(col("date_value")).alias("month"),
            date_format(col("date_value"), 'MMMM').alias("month_name"),
            year(col("date_value")).alias("year"),
            quarter(col("date_value")).alias("quarter"),
            date_format(col("date_value"), 'E').alias("day_of_week")
        )
)

display(calendar_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date_id</th><th>date_value</th><th>month</th><th>month_name</th><th>year</th><th>quarter</th><th>day_of_week</th></tr></thead><tbody><tr><td>20130201</td><td>2013-02-01</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Fri</td></tr><tr><td>20130202</td><td>2013-02-02</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Sat</td></tr><tr><td>20130203</td><td>2013-02-03</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Sun</td></tr><tr><td>20130204</td><td>2013-02-04</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Mon</td></tr><tr><td>20130205</td><td>2013-02-05</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Tue</td></tr><tr><td>20130206</td><td>2013-02-06</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Wed</td></tr><tr><td>20130207</td><td>2013-02-07</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Thu</td></tr><tr><td>20130208</td><td>2013-02-08</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Fri</td></tr><tr><td>20130209</td><td>2013-02-09</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Sat</td></tr><tr><td>20130210</td><td>2013-02-10</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Sun</td></tr><tr><td>20130211</td><td>2013-02-11</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Mon</td></tr><tr><td>20130212</td><td>2013-02-12</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Tue</td></tr><tr><td>20130213</td><td>2013-02-13</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Wed</td></tr><tr><td>20130214</td><td>2013-02-14</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Thu</td></tr><tr><td>20130215</td><td>2013-02-15</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Fri</td></tr><tr><td>20130216</td><td>2013-02-16</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Sat</td></tr><tr><td>20130217</td><td>2013-02-17</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Sun</td></tr><tr><td>20130218</td><td>2013-02-18</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Mon</td></tr><tr><td>20130219</td><td>2013-02-19</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Tue</td></tr><tr><td>20130220</td><td>2013-02-20</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Wed</td></tr><tr><td>20130221</td><td>2013-02-21</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Thu</td></tr><tr><td>20130222</td><td>2013-02-22</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Fri</td></tr><tr><td>20130223</td><td>2013-02-23</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Sat</td></tr><tr><td>20130224</td><td>2013-02-24</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Sun</td></tr><tr><td>20130225</td><td>2013-02-25</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Mon</td></tr><tr><td>20130226</td><td>2013-02-26</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Tue</td></tr><tr><td>20130227</td><td>2013-02-27</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Wed</td></tr><tr><td>20130228</td><td>2013-02-28</td><td>2</td><td>February</td><td>2013</td><td>1</td><td>Thu</td></tr><tr><td>20130301</td><td>2013-03-01</td><td>3</td><td>March</td><td>2013</td><td>1</td><td>Fri</td></tr><tr><td>20130302</td><td>2013-03-02</td><td>3</td><td>March</td><td>2013</td><td>1</td><td>Sat</td></tr><tr><td>20130303</td><td>2013-03-03</td><td>3</td><td>March</td><td>2013</td><td>1</td><td>Sun</td></tr><tr><td>20130304</td><td>2013-03-04</td><td>3</td><td>March</td><td>2013</td><td>1</td><td>Mon</td></tr><tr><td>20130305</td><td>2013-03-05</td><td>3</td><td>March</td><td>2013</td><td>1</td><td>Tue</td></tr><tr><td>20130306</td><td>2013-03-06</td><td>3</td><td>March</td><td>2013</td><td>1</td><td>Wed</td></tr><tr><td>20130307</td><td>2013-03-07</td><td>3</td><td>March</td><td>2013</td><td>1</td><td>Thu</td></tr><tr><td>20130308</td><td ...

# %%
# Create Database to load Gold Tables
spark.sql("CREATE DATABASE IF NOT EXISTS Gold_Store")

# Use Gold Store to load dimension tables and fact tables that are part of the designed star schema
spark.sql("USE DATABASE Gold_Store")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: DataFrame[]</div>

# %%
# Save calendar dataframe to delta table in Gold Store.
(calendar_df
     .write
     .format("delta")
     .mode("overwrite")
     .saveAsTable("dim_date")
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
