# %% [markdown]
# ### Import date din fisiere .csv

# %%
import pandas as pd

# %%
path = 'C:\\Users\\anlazar\\Full_Archive\\New Files\\olist db\\'

# %%
customers_df = pd.read_csv(filepath_or_buffer=path+'olist_customers_dataset.csv')

# %%
customers_df.head()
# Out:
#    customer_id  customer_unique_id  customer_zip_code_prefix  \
# 0        49567               48030                     81560
# 1        46861               45424                     30575
# 2        38631               37457                     39400
# 3        54148               52453                     20231
# 4        24363               23670                     18682
#
#       customer_city customer_state
# 0          curitiba             PR
# 1    belo horizonte             MG
# 2     montes claros             MG
# 3    rio de janeiro             RJ
# 4  lencois paulista             SP

# %%
customers_df = pd.read_csv(filepath_or_buffer=path+'olist_customers_dataset.csv',
                           usecols = ['customer_unique_id', 'customer_city', 'customer_state'])
customers_df.head()
# Out:
#    customer_unique_id     customer_city customer_state
# 0               48030          curitiba             PR
# 1               45424    belo horizonte             MG
# 2               37457     montes claros             MG
# 3               52453    rio de janeiro             RJ
# 4               23670  lencois paulista             SP

# %%
customers_df = pd.read_csv(filepath_or_buffer = path + 'olist_customers_dataset.csv',
                           nrows = 1000,
                           usecols = ['customer_unique_id', 'customer_city', 'customer_state'])
customers_df
# Out:
#      customer_unique_id     customer_city customer_state
# 0                 48030          curitiba             PR
# 1                 45424    belo horizonte             MG
# 2                 37457     montes claros             MG
# 3                 52453    rio de janeiro             RJ
# 4                 23670  lencois paulista             SP
# ..                  ...               ...            ...
# 995               57553         sao paulo             SP
# 996                 177    rio de janeiro             RJ
# 997               63404         joinville             SC
# 998                5759         sao paulo             SP
# 999               27025        vila velha             ES
#
# [1000 rows x 3 columns]

# %%
customers_df_header = pd.read_csv(filepath_or_buffer = path + 'olist_customers_dataset.csv', 
                                  nrows = 0)
customers_df_header
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
customers_df = pd.read_csv(filepath_or_buffer = path + 'olist_customers_dataset.csv',
                           nrows = 1000,
                           skiprows = 1000,
                           header = customers_df_header)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18308/170872076.py in <module>
# ----> 1 customers_df = pd.read_csv(filepath_or_buffer = path + 'olist_customers_dataset.csv',
#       2                            nrows = 1000,
#       3                            skiprows = 1000,
#       4                            header = customers_df_header)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
customers_df = pd.concat([customers_df_header,
                        pd.read_csv(filepath_or_buffer = path + 'olist_customers_dataset.csv',
                                    nrows = 1000,
                                    skiprows = 1000)
                         ]
                         )
customers_df
# Out:
#     customer_id customer_unique_id customer_zip_code_prefix customer_city  \
# 0           NaN                NaN                      NaN           NaN
# 1           NaN                NaN                      NaN           NaN
# 2           NaN                NaN                      NaN           NaN
# 3           NaN                NaN                      NaN           NaN
# 4           NaN                NaN                      NaN           NaN
# ..          ...                ...                      ...           ...
# 995         NaN                NaN                      NaN           NaN
# 996         NaN                NaN                      NaN           NaN
# 997         NaN                NaN                      NaN           NaN
# 998         NaN                NaN                      NaN           NaN
# 999         NaN                NaN                      NaN           NaN
#
#     customer_state    27843    27025    29101             vila velha  ES
# ...

# %%
customers_df_header = pd.read_csv(filepath_or_buffer = path + 'olist_customers_dataset.csv', 
                                  nrows = 1).columns.values
customers_df_header
#type(customers_df_header)
# Out:
# array(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'], dtype=object)

# %%
customers_df = pd.read_csv(filepath_or_buffer = path + 'olist_customers_dataset.csv',
                            nrows = 1000,
                            skiprows = 1000,
                           names = customers_df_header
                           )
customers_df
# Out:
#      customer_id  customer_unique_id  customer_zip_code_prefix  \
# 0          27843               27025                     29101
# 1          76148               73665                     88501
# 2          12896               12586                     24240
# 3          38039               36879                     49015
# 4          60800               58827                     26052
# ..           ...                 ...                       ...
# 995        82302               79580                      3738
# 996        32207               31237                     82920
# 997        21218               20642                     20080
# 998        98830               95531                     18125
# 999        98636               95343                      5029
#
#       customer_city customer_state
# 0        vila velha             ES
# 1             lages             SC
# 2           niteroi             RJ
# 3           aracaju             SE
# ...

# %%
customers_df = pd.read_csv(filepath_or_buffer = path + 'olist_customers_dataset.csv',
                            nrows = 1000,
                            skiprows = range(1, 1000)
                           )

# %%
customers_df
# Out:
#      customer_id  customer_unique_id  customer_zip_code_prefix  \
# 0          27843               27025                     29101
# 1          76148               73665                     88501
# 2          12896               12586                     24240
# 3          38039               36879                     49015
# 4          60800               58827                     26052
# ..           ...                 ...                       ...
# 995        82302               79580                      3738
# 996        32207               31237                     82920
# 997        21218               20642                     20080
# 998        98830               95531                     18125
# 999        98636               95343                      5029
#
#       customer_city customer_state
# 0        vila velha             ES
# 1             lages             SC
# 2           niteroi             RJ
# 3           aracaju             SE
# ...

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               1000 non-null   int64
#  1   customer_unique_id        1000 non-null   int64
#  2   customer_zip_code_prefix  1000 non-null   int64
#  3   customer_city             1000 non-null   object
#  4   customer_state            1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
customers_df = pd.read_csv(filepath_or_buffer = path + 'olist_customers_dataset.csv')
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99431 entries, 0 to 99430
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99431 non-null  int64
#  1   customer_unique_id        99431 non-null  int64
#  2   customer_zip_code_prefix  99431 non-null  int64
#  3   customer_city             99431 non-null  object
#  4   customer_state            99431 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 3.8+ MB

# %%
customers_df = pd.read_csv(filepath_or_buffer = path + 'olist_customers_dataset.csv',
                           dtype = {'customer_unique_id':'uint32',
                                    'customer_id':'uint32',
                                    'customer_zip_code_prefix':'uint32',
                                    'customer_city':'category',
                                    'customer_state':'category'}
                          )
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99431 entries, 0 to 99430
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99431 non-null  uint32
#  1   customer_unique_id        99431 non-null  uint32
#  2   customer_zip_code_prefix  99431 non-null  uint32
#  3   customer_city             99431 non-null  category
#  4   customer_state            99431 non-null  category
# dtypes: category(2), uint32(3)
# memory usage: 1.6 MB

# %%
customers_df['customer_city'].unique()
# Out:
# <StringArray>
# [           'curitiba',      'belo horizonte',       'montes claros',
#       'rio de janeiro',    'lencois paulista',           'sao paulo',
#        'caxias do sul',          'piracicaba',           'guarulhos',
#               'pacaja',
#  ...
#             'balbinos',        'serra bonita',        'venda branca',
#          'sanga puita',             'queiroz',              'siriji',
#  'natividade da serra',        'monte bonito',          'sao rafael',
#    'eugenio de castro']
# Length: 4119, dtype: string

# %%
customers_df['customer_state'].unique()
# Out:
# <StringArray>
# ['PR', 'MG', 'RJ', 'SP', 'RS', 'PA', 'SC', 'GO', 'ES', 'BA', 'MA', 'MS', 'CE',
#  'DF', 'RN', 'PE', 'MT', 'AM', 'AP', 'AL', 'RO', 'PB', 'TO', 'PI', 'AC', 'SE',
#  'RR']
# Length: 27, dtype: string

# %%
import numpy as np

# %%
np.iinfo('uint32')
# Out:
# iinfo(min=0, max=4294967295, dtype=uint32)

# %%
customers_df.sample(n=100)
# Out:
#        customer_id  customer_unique_id  customer_zip_code_prefix  \
# 91603          126                 233                       254
# 71690          233                  36                       170
# 26463          124                  30                       203
# 46509          132                  98                       109
# 67258          157                 152                        36
# ...            ...                 ...                       ...
# 74944          105                 193                       198
# 27833          188                  54                       188
# 66081          154                 186                       208
# 51580           33                 224                        82
# 2844            31                 248                       229
#
#            customer_city customer_state
# 91603          sao paulo             SP
# 71690       caldas novas             GO
# 26463          sao paulo             SP
# ...

# %%
1.6/3.8
# Out:
# 0.4210526315789474

# %%
np.finfo('float32')
# Out:
# finfo(resolution=1e-06, min=-3.4028235e+38, max=3.4028235e+38, dtype=float32)

# %%
from datetime import datetime

# %%
orders_df = pd.read_csv(filepath_or_buffer=path+'olist_orders_dataset.csv', 
                        #nrows = 5,
                        parse_dates = list(range(3, 8)),
                        na_values = {'order_approved_at':datetime(9999,12,31),
                                     'order_delivered_carrier_date':datetime(9999,12,31),
                                     'order_delivered_customer_date':datetime(9999,12,31)
                                    }
                       )
orders_df.head(10)
# Out:
#    order_id  customer_id order_status order_purchase_timestamp  \
# 0         1            1      shipped      2016-09-04 21:15:00
# 1         2            2     canceled      2016-09-05 00:15:00
# 2         3            3     canceled      2016-09-13 15:24:00
# 3         4            4    delivered      2016-09-15 12:16:00
# 4         5            5     canceled      2016-10-02 22:07:00
# 5         6            6    delivered      2016-10-03 09:44:00
# 6         7            7    delivered      2016-10-03 16:56:00
# 7         8            8     canceled      2016-10-03 21:01:00
# 8         9            9    delivered      2016-10-03 21:13:00
# 9        10           10    delivered      2016-10-03 22:06:00
#
#     order_approved_at order_delivered_carrier_date  \
# 0 2016-10-07 13:18:00          2016-10-18 13:14:00
# 1 2016-10-07 13:17:00                          NaT
# 2 2016-10-07 13:16:00                          NaT
# 3 2016-09-15 12:16:00          2016-11-07 17:11:00
# ...

# %%
for item in pd.read_csv(filepath_or_buffer = path+'olist_orders_dataset.csv', chunksize = 1000):
    print(item)
# Out:
#      order_id  customer_id order_status order_purchase_timestamp  \
# 0           1            1      shipped           9/4/2016 21:15
# 1           2            2     canceled            9/5/2016 0:15
# 2           3            3     canceled          9/13/2016 15:24
# 3           4            4    delivered          9/15/2016 12:16
# 4           5            5     canceled          10/2/2016 22:07
# ..        ...          ...          ...                      ...
# 995       996          996    delivered          1/29/2017 20:03
# 996       997          997    delivered          1/29/2017 20:14
# 997       998          998    delivered          1/29/2017 20:24
# 998       999          999    delivered          1/29/2017 20:37
# 999      1000         1000    delivered          1/29/2017 20:53
#
#     order_approved_at order_delivered_carrier_date  \
# 0     10/7/2016 13:18             10/18/2016 13:14
# 1     10/7/2016 13:17                          NaN
# ...

# %%
df_list = []

for item in pd.read_csv(filepath_or_buffer = path+'olist_customers_dataset.csv', chunksize = 1000):
    df_list.append(item.loc[item['customer_state'] == 'SP'])

(
pd.concat(objs = df_list, ignore_index = True)
    .to_csv(path + 'olist_customers_filtered_SP.csv', index = False)
)

pd.read_csv(path + 'olist_customers_filtered_SP.csv')
# Out:
#        customer_id  customer_unique_id  customer_zip_code_prefix  \
# 0            24363               23670                     18682
# 1            61088               59106                      5704
# 2            81464               59106                      5704
# 3            52129               50507                     13412
# 4            84003               81225                      7124
# ...            ...                 ...                       ...
# 41735        60725               58753                     13500
# 41736        78610               76052                      7790
# 41737        68172               65961                      3937
# 41738        67399               65218                      6764
# 41739        43856               42499                      6703
#
#           customer_city customer_state
# 0      lencois paulista             SP
# 1             sao paulo             SP
# 2             sao paulo             SP
# ...

# %%
customers_df.to

# %% [markdown]
# ### Import/export fisiere excel

# %%
customers_orders_df = pd.read_excel(io = path + 'olist_customers_orders_dataset.xlsx')
customers_orders_df
# Out:
#         Unnamed: 0          Unnamed: 1                Unnamed: 2  \
# 0              NaN                 NaN                       NaN
# 1      customer_id  customer_unique_id  customer_zip_code_prefix
# 2            15229               14846                     35701
# 3            15228               14845                     60321
# 4            15226               14844                     26430
# ...            ...                 ...                       ...
# 14891            5                   5                      2975
# 14892            4                   4                     14600
# 14893            3                   3                     12244
# 14894            2                   2                     99025
# 14895            1                   1                     69309
#
#                  Unnamed: 3      Unnamed: 4
# 0                       NaN             NaN
# 1             customer_city  customer_state
# 2               sete lagoas              MG
# ...

# %%
customers_orders_df = pd.read_excel(io = path + 'olist_customers_orders_dataset.xlsx',
                                    skiprows = 2)
customers_orders_df
# Out:
#        customer_id  customer_unique_id  customer_zip_code_prefix  \
# 0            15229               14846                     35701
# 1            15228               14845                     60321
# 2            15226               14844                     26430
# 3            15225               14843                      9406
# 4            15224               14842                      8410
# ...            ...                 ...                       ...
# 14889            5                   5                      2975
# 14890            4                   4                     14600
# 14891            3                   3                     12244
# 14892            2                   2                     99025
# 14893            1                   1                     69309
#
#               customer_city customer_state
# 0               sete lagoas             MG
# 1                 fortaleza             CE
# 2                    japeri             RJ
# ...

# %%
customers_orders_df = pd.read_excel(io = path + 'olist_customers_orders_dataset.xlsx',
                                    skiprows = 2,
                                    usecols = ['customer_id', 'customer_unique_id'])
customers_orders_df
# Out:
#        customer_id  customer_unique_id
# 0            15229               14846
# 1            15228               14845
# 2            15226               14844
# 3            15225               14843
# 4            15224               14842
# ...            ...                 ...
# 14889            5                   5
# 14890            4                   4
# 14891            3                   3
# 14892            2                   2
# 14893            1                   1
#
# [14894 rows x 2 columns]

# %%
customers_orders_df = pd.read_excel(io = path + 'olist_customers_orders_dataset.xlsx',
                                    skiprows = 2,
                                    usecols = 'A, B, D, E')
customers_orders_df
# Out:
#        customer_id  customer_unique_id         customer_city customer_state
# 0            15229               14846           sete lagoas             MG
# 1            15228               14845             fortaleza             CE
# 2            15226               14844                japeri             RJ
# 3            15225               14843        ribeirao pires             SP
# 4            15224               14842             sao paulo             SP
# ...            ...                 ...                   ...            ...
# 14889            5                   5             sao paulo             SP
# 14890            4                   4  sao joaquim da barra             SP
# 14891            3                   3   sao jose dos campos             SP
# 14892            2                   2           passo fundo             RS
# 14893            1                   1             boa vista             RR
#
# [14894 rows x 4 columns]

# %%
customers_df = pd.read_excel(io = path + 'olist_customers_orders_dataset.xlsx',
                                    skiprows = 2,
                                    usecols = 'A, B, D, E')

# %%
orders_df = pd.read_excel(io = path + 'olist_customers_orders_dataset.xlsx',
                          sheet_name = 1) #sheet_name = 'orders'

# %%
orders_df
# Out:
#        order_id  customer_id order_status order_purchase_timestamp  \
# 0             1            1      shipped      2016-04-09 21:15:00
# 1             2            2     canceled      2016-05-09 00:15:00
# 2             3            3     canceled          9/13/2016 15:24
# 3             4            4    delivered          9/15/2016 12:16
# 4             5            5     canceled      2016-02-10 22:07:00
# ...         ...          ...          ...                      ...
# 15224     15225        15225    delivered      2017-03-07 20:36:00
# 15225     15226        15226    delivered      2017-03-07 20:49:00
# 15226     15227        15227    delivered      2017-03-07 20:50:00
# 15227     15228        15228    delivered      2017-03-07 21:01:00
# 15228     15229        15229    delivered      2017-03-07 21:12:00
#
#          order_approved_at order_delivered_carrier_date  \
# 0      2016-07-10 13:18:00             10/18/2016 13:14
# ...

# %%
xlsx = pd.ExcelFile(path_or_buffer = path + 'olist_customers_orders_dataset.xlsx')

# %%
xlsx.sheet_names
# Out:
# ['customers', 'orders']

# %%
for sheet_name in pd.ExcelFile(path_or_buffer = path + 'olist_customers_orders_dataset.xlsx').sheet_names:
    globals()[sheet_name + '_df'] = pd.read_excel(io = path + 'olist_customers_orders_dataset.xlsx',
                                           sheet_name = sheet_name)

# %%
customers_df = customers_df.iloc[2:]

# %%
customers_df.iloc[1].values
# Out:
# array(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'], dtype=object)

# %%
customers_df.columns = customers_df.iloc[1].values
customers_df=customers_df.iloc[2:]
customers_df=customers_df.reset_index(drop = True)

# %%
customers_df
# Out:
#       customer_id customer_unique_id customer_zip_code_prefix  \
# 0           15229              14846                    35701
# 1           15228              14845                    60321
# 2           15226              14844                    26430
# 3           15225              14843                     9406
# 4           15224              14842                     8410
# ...           ...                ...                      ...
# 14889           5                  5                     2975
# 14890           4                  4                    14600
# 14891           3                  3                    12244
# 14892           2                  2                    99025
# 14893           1                  1                    69309
#
#               customer_city customer_state
# 0               sete lagoas             MG
# 1                 fortaleza             CE
# 2                    japeri             RJ
# 3            ribeirao pires             SP
# ...

# %%
orders_df
# Out:
#        order_id  customer_id order_status order_purchase_timestamp  \
# 0             1            1      shipped      2016-04-09 21:15:00
# 1             2            2     canceled      2016-05-09 00:15:00
# 2             3            3     canceled          9/13/2016 15:24
# 3             4            4    delivered          9/15/2016 12:16
# 4             5            5     canceled      2016-02-10 22:07:00
# ...         ...          ...          ...                      ...
# 15224     15225        15225    delivered      2017-03-07 20:36:00
# 15225     15226        15226    delivered      2017-03-07 20:49:00
# 15226     15227        15227    delivered      2017-03-07 20:50:00
# 15227     15228        15228    delivered      2017-03-07 21:01:00
# 15228     15229        15229    delivered      2017-03-07 21:12:00
#
#          order_approved_at order_delivered_carrier_date  \
# 0      2016-07-10 13:18:00             10/18/2016 13:14
# ...

# %%
customers_df.iloc[30:40].to_excel(path+'customers_filtered.xlsx', index = False)

# %%
pd.ExcelWriter()

# %% [markdown]
# ### Import date din tabele din pagini web

# %%
vw_tables = pd.read_html(io = 'https://en.wikipedia.org/wiki/Volkswagen_Group')

# %%
vw_tables[1]
# Out:
#     Year  Revenuein bn. EUR€[70] Net incomein bn. EUR€[71]  Employees[72]
# 0   1990                  34.800                       NaN         261000
# 1   2000                  81.840                     2.610         322000
# 2   2001                  87.300                     2.930         324000
# 3   2002                  85.293                     2.597         324000
# 4   2003                  84.813                     1.003         335000
# 5   2004                  88.963                     0.697         343000
# 6   2005                  93.996                     1.120         345000
# 7   2006                 104.875                     2.750         324900
# 8   2007                 108.897                     4.122         329300
# 9   2008                 113.808                     4.688         369900
# 10  2009                 105.187                     0.911         368500
# 11  2010                 126.875                     7.226         399400
# ...

# %%
vw_tables[1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       23 non-null     int64
#  1   Revenuein bn. EUR€[70]     23 non-null     float64
#  2   Net incomein bn. EUR€[71]  22 non-null     object
#  3   Employees[72]              23 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 864.0+ bytes

# %%
(
vw_tables[1]
    .set_index(keys = 'Year')
    .loc['2017':]
    [['Revenuein bn. EUR€[70]', 'Employees[72]']]
    .mean()
    .to_frame()
)
# Out:
#                                   0
# Revenuein bn. EUR€[70]     238.4496
# Employees[72]           659400.0000

# %%
order_items_df = pd.read_csv(filepath_or_buffer=path+'olist_order_items_dataset.csv')
order_items_df
# Out:
#         order_id  order_item_id  product_id  seller_id shipping_limit_date  \
# 0              1              1       24855        247    10/26/2016 18:25
# 1             35              1       24855        247     10/14/2016 2:44
# 2            319              1       24855        247    10/26/2016 16:35
# 3            376              2       24855        247      1/13/2017 0:37
# 4            376              1       24855        247      1/13/2017 0:37
# ...          ...            ...         ...        ...                 ...
# 112645     99171              1       31312        461     8/31/2018 13:04
# 112646     99214              1       24923       2201     8/31/2018 10:44
# 112647     99246              1       10892       2813     8/30/2018 14:25
# 112648     99307              1       22344        595     8/30/2018 13:15
# 112649     99365              1       13147       1237       9/3/2018 9:44
#
#          price  freight_value
# 0        39.99          31.67
# ...

# %%
conv_data = pd.read_html(io = 'https://www.xe.com/currencyconverter/convert/?Amount=1&From=BRL&To=EUR')
conv_data
# Out:
# [           BRL           EUR
#  0        1 BRL  0.196711 EUR
#  1        5 BRL  0.983553 EUR
#  2       10 BRL   1.96711 EUR
#  3       25 BRL   4.91776 EUR
#  4       50 BRL   9.83553 EUR
#  5      100 BRL   19.6711 EUR
#  6      500 BRL   98.3553 EUR
#  7    1,000 BRL   196.711 EUR
#  8    5,000 BRL   983.553 EUR
#  9   10,000 BRL  1,967.11 EUR
#  10  50,000 BRL  9,835.53 EUR,
#             EUR           BRL
#  0        1 EUR   5.08361 BRL
#  1        5 EUR   25.4181 BRL
#  2       10 EUR   50.8361 BRL
#  3       25 EUR    127.09 BRL
#  4       50 EUR   254.181 BRL
#  5      100 EUR   508.361 BRL
#  6      500 EUR  2,541.81 BRL
#  7    1,000 EUR  5,083.61 BRL
#  8    5,000 EUR  25,418.1 BRL
#  9   10,000 EUR  50,836.1 BRL
#  10  50,000 EUR   254,181 BRL,
#                                            Unnamed: 0 Last 30 Days Last 90 Days
#  0  HighThese are the highest points the exchange ...      0.19805      0.19805
# ...

# %%
conv_df = conv_data[0]
conv_df
# Out:
#            BRL           EUR
# 0        1 BRL  0.196711 EUR
# 1        5 BRL  0.983553 EUR
# 2       10 BRL   1.96711 EUR
# 3       25 BRL   4.91776 EUR
# 4       50 BRL   9.83553 EUR
# 5      100 BRL   19.6711 EUR
# 6      500 BRL   98.3553 EUR
# 7    1,000 BRL   196.711 EUR
# 8    5,000 BRL   983.553 EUR
# 9   10,000 BRL  1,967.11 EUR
# 10  50,000 BRL  9,835.53 EUR

# %%
conv_ser = conv_df.iloc[0]
conv_ser
# Out:
# BRL           1 BRL
# EUR    0.196711 EUR
# Name: 0, dtype: object

# %%
conv_rate = conv_ser['EUR']
conv_rate
# Out:
# '0.196711 EUR'

# %%
conv_rate_float = float(conv_rate.replace(' EUR', ''))
conv_rate_float
# Out:
# 0.196711

# %%
conv_rate_float = float(
                        pd.read_html(io = 'https://www.xe.com/currencyconverter/convert/?Amount=1&From=BRL&To=EUR')
                            [0]
                            .iloc[0, 1]
                            .replace(' EUR', '')
                        )
# Out:
# 0.196711

# %%
customers_df = pd.read_csv(path + 'olist_customers_dataset.csv', usecols = ['customer_id', 'customer_state'])
orders_df = pd.read_csv(path + 'olist_orders_dataset.csv', usecols = ['customer_id', 'order_id'])

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
(order_items_df
 .merge(right = orders_df)
 .merge(right = customers_df)
 [['customer_state', 'price']]
 .groupby(by = 'customer_state')
 .sum()
 [['price']]
 .rename(columns = {'price':'sales (EUR)'})
 *conv_rate_float
)
# Out:
#                 sales (EUR)
# customer_state
# AC                  3144.02
# AL                 15798.81
# AM                  4397.84
# AP                  2650.54
# BA                100588.17
# CE                 44703.50
# DF                 59525.52
# ES                 54102.86
# GO                 57949.48
# MA                 23536.12
# MG                311843.61
# MS                 22978.33
# MT                 30776.13
# PA                 35201.00
# PB                 22674.50
# PE                 51693.30
# PI                 17096.96
# PR                134365.17
# RJ                358819.09
# RN                 16333.89
# RO                  9076.37
# RR                  1540.14
# RS                147593.05
# SC                102298.93
# SE                 11590.38
# SP               1023291.84
# TO                  9761.14

# %%
beautifulsoup
scrappy

# %% [markdown]
# ### Import/export baze de date relationale

# %%
import sqlite3 as sq3

# %%
connection = sq3.connect(database = 'olist_orders.db')

# %%
connection.execute(" select name from sqlite_master where type = 'table' ").fetchall()
# Out:
# []

# %%
import os

# %%
os.listdir(path)
# Out:
# ['customers_filtered.xlsx',
#  'customers_filtered_SP.csv',
#  'olist_closed_deals_dataset.xlsx',
#  'olist_customers_dataset.csv',
#  'olist_customers_filtered_SP.csv',
#  'olist_customers_orders_dataset.xlsx',
#  'olist_geolocation_dataset.csv',
#  'olist_marketing_qualified_leads_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_products_dataset.csv',
#  'olist_product_category_name_translation.csv',
#  'olist_sellers_dataset.csv',
#  'orders_reduced_dataset.xlsx']

# %%
for file_name in os.listdir(path):
    if 'dataset.csv' in file_name or 'translation' in file_name:
        (pd.read_csv(path+file_name) #-->returneaza dataframe
            .to_sql(name = file_name.replace('olist_', '')
                                    .replace('.csv', '')
                                    .replace('_dataset', ''), 
                    con = connection, 
                    index = False)
        )

# %%
pd.read_sql(sql = "select * from sqlite_master where type = 'table' ", con = connection)
#alternativ: connection.execute(" select name from sqlite_master where type = 'table' ").fetchall()
# Out:
#     type                               name  \
# 0  table                          customers
# 1  table                        geolocation
# 2  table          marketing_qualified_leads
# 3  table                             orders
# 4  table                        order_items
# 5  table                     order_payments
# 6  table                      order_reviews
# 7  table                           products
# 8  table  product_category_name_translation
# 9  table                            sellers
#
#                             tbl_name  rootpage  \
# 0                          customers         2
# 1                        geolocation       784
# 2          marketing_qualified_leads      5824
# 3                             orders      5889
# 4                        order_items      8389
# 5                     order_payments      9757
# 6                      order_reviews     10592
# 7                           products     11669
# ...

# %%
connection.execute(" select name from sqlite_master where type = 'table' ").fetchall()
# Out:
# [('customers',),
#  ('geolocation',),
#  ('marketing_qualified_leads',),
#  ('orders',),
#  ('order_items',),
#  ('order_payments',),
#  ('order_reviews',),
#  ('products',),
#  ('product_category_name_translation',),
#  ('sellers',)]

# %%
pd.read_sql(sql = """
                     select count(*)
                     from orders
                     where order_status = 'delivered'
                    """, con = connection)
# Out:
#    count(*)
# 0     96478

# %%
pd.read_sql(sql = """
                    select order_status, count(*) as cnt
                    from orders
                    group by order_status
                    order by cnt desc
                    """, con = connection)
# Out:
#   order_status    cnt
# 0    delivered  96478
# 1      shipped   1107
# 2     canceled    625
# 3  unavailable    609
# 4     invoiced    314
# 5   processing    301
# 6      created      5
# 7     approved      2

# %%
for name in pd.read_sql(sql = "select name from sqlite_master where type = 'table' ", con = connection)['name']:
    print(name)
# Out:
# customers
# geolocation
# marketing_qualified_leads
# orders
# order_items
# order_payments
# order_reviews
# products
# product_category_name_translation
# sellers

# %%
for table in pd.read_sql(sql = "select name from sqlite_master where type = 'table' ", con = connection)['name']:
    print(pd.read_sql(f"select '{table}' as table_name, count(*) as cnt from {table}", con = connection), '\n')
# Out:
#   table_name    cnt
# 0  customers  99431
#
#     table_name     cnt
# 0  geolocation  720156
#
#                   table_name   cnt
# 0  marketing_qualified_leads  8000
#
#   table_name    cnt
# 0     orders  99441
#
#     table_name     cnt
# 0  order_items  112650
#
#        table_name     cnt
# 0  order_payments  103886
#
#       table_name     cnt
# 0  order_reviews  100000
#
#   table_name    cnt
# 0   products  32951
#
#                           table_name  cnt
# 0  product_category_name_translation   71
#
#   table_name   cnt
# 0    sellers  3095
