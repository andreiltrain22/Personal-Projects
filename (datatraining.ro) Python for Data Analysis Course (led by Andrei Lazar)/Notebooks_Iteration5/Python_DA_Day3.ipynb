# %% [markdown]
# ## Serii Pandas

# %%
import pandas as pd

# %%
no_contracts_dict = {'Andrew':40, 'Bobo':57, 'Claire':64, 'David':22}

# %%
type(no_contracts_dict)
# Out:
# dict

# %%
contracts_ser = pd.Series(data = no_contracts_dict)
contracts_ser
# Out:
# Andrew    40
# Bobo      57
# Claire    64
# David     22
# dtype: int64

# %% [markdown]
# Ex: Se considera vanzarile unei companii globale pe primele 2 trimestre din anul in curs. Sa se determine:
# - vanzarile doar pentru Japonia din q1
# - vanzarile pentru Franta in q1
# - vanzarile pentru USA (scris cu spatiu la final si scris cu minuscule) pentru q2
# - stiind ca vanzarile din q3 sunt dublate fata de q1, sa se determine vanzarile din q3
# - vanzarile q1 si q2 cumulate
# - ce se intampla in cazul in care o tara nu are vanzari in q1 sau q2

# %%
q1_sales_dict = {'Japan':80, 'China':450, 'India':200, 'USA':250} 
q2_sales_dict = {'Brazil':100, 'China':500, 'India':210, 'USA':260}

# %%
q1_sales_ser = pd.Series(data = q1_sales_dict)
q2_sales_ser = pd.Series(data = q2_sales_dict)

# %%
q1_sales_ser
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
q2_sales_ser
# Out:
# Brazil    100
# China     500
# India     210
# USA       260
# dtype: int64

# %%
q1_sales_ser['Japan']
# Out:
# 80

# %%
type(q1_sales_ser[['Japan']]) #[] exterior - operator de indexare; [] - lista
# Out:
# pandas.core.series.Series

# %%
q1_sales_ser['France']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'France'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
q2_sales_ser['usa']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'usa'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
q2_sales_ser['USA ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'USA '
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sales_q3_ser = q1_sales_ser * 2
sales_q3_ser
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
q1_sales_ser + q2_sales_ser #NaN - not a number; echivalentul NULL din SQL
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
q1_sales_ser.add(other = q2_sales_ser, fill_value = 0) #Shift+Tab intre paranteze
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %% [markdown]
# ## Dataframe

# %%
path = 'C:\\Users\\anlazar\\Full_Archive\\New Files\\'
#alternative: 'C:/Users/anlazar/Full_Archive/New Files/'
#alternative: r'C:\Users\anlazar\Full_Archive\New Files\'

# %%
path+'tips.csv'
# Out:
# 'C:\\Users\\anlazar\\Full_Archive\\New Files\\tips.csv'

# %%
tips_df = pd.read_csv(path+'tips.csv')

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 248       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 249       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 250       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 251       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 252       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
tips_df.index
# Out:
# RangeIndex(start=0, stop=253, step=1)

# %%
tips_df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %% [markdown]
# ### Inspectie dataframe

# %%
tips_df.head(n=10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
tips_df.tail(n=8)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 245       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 246       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 247       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 248       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 249       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 250       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 251       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 252       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 245    Matthew Myers  3543676378973960    Sat5032
# 246     Thomas Brown  4284722681265500    Sat2929
# 247   Kimberly Crane      676184013727    Sat9777
# 248    Michael Avila  5296068606052840    Sat2657
# ...

# %%
tips_df.sample(n=15)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 50        12.54  2.50    Male     No   Sun  Dinner     2              6.27
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2              8.14
# 177       14.48  2.00    Male    Yes   Sun  Dinner     2              7.24
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4              9.68
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# 151       13.13  2.00    Male     No   Sun  Dinner     2              6.56
# 48        28.55  2.05    Male     No   Sun  Dinner     3              9.52
# 29        19.65  3.00  Female     No   Sat  Dinner     2              9.82
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 33        20.69  2.45  Female     No   Sat  Dinner     4              5.17
# 248       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# ...

# %%
tips_df.sample(frac = 0.1)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 98        21.01   3.00    Male    Yes   Fri  Dinner     2             10.50
# 230       24.01   2.00    Male    Yes   Sat  Dinner     4              6.00
# 96        27.28   4.00    Male    Yes   Fri  Dinner     2             13.64
# 233       10.77   1.47    Male     No   Sat  Dinner     2              5.38
# 207       38.73   3.00    Male    Yes   Sat  Dinner     4              9.68
# 116       29.93   5.07    Male     No   Sun  Dinner     4              7.48
# 169       10.63   2.00  Female    Yes   Sat  Dinner     2              5.32
# 2         21.01   3.50    Male     No   Sun  Dinner     3              7.00
# 195        7.56    NaN    Male     No  Thur   Lunch     2              3.78
# 180       34.65   3.68    Male    Yes   Sun  Dinner     4              8.66
# 160       21.50   3.50    Male     No   Sun  Dinner     4              5.38
# ...

# %%
tips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        253 non-null    float64
#  1   tip               237 non-null    float64
#  2   sex               253 non-null    object
#  3   smoker            253 non-null    object
#  4   day               253 non-null    object
#  5   time              253 non-null    object
#  6   size              253 non-null    int64
#  7   price_per_person  253 non-null    float64
#  8   Payer Name        253 non-null    object
#  9   CC Number         253 non-null    int64
#  10  Payment ID        253 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.9+ KB

# %%
len(tips_df)
# Out:
# 253

# %%
tips_df.shape
# Out:
# (253, 11)

# %%
tips_df.describe(include = 'all')
# Out:
#         total_bill         tip   sex smoker  day    time        size  \
# count   253.000000  237.000000   253    253  253     253  253.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   163    156   95     185         NaN
# mean     19.899526    2.981561   NaN    NaN  NaN     NaN    2.557312
# std       8.904724    1.409213   NaN    NaN  NaN     NaN    0.939476
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.370000    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.820000    2.830000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.520000    3.510000   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000
#
#         price_per_person       Payer Name     CC Number Payment ID
# count         253.000000              253  2.530000e+02        253
# ...

# %% [markdown]
# ### Selectie coloane

# %%
type(tips_df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
tips_df['total_bill'] #dataframe['coloana']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 248    29.03
# 249    27.18
# 250    22.67
# 251    17.82
# 252    18.78
# Name: total_bill, Length: 253, dtype: float64

# %%
type(tips_df)
# Out:
# pandas.core.frame.DataFrame

# %%
tips_df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 248       29.03  5.92
# 249       27.18  2.00
# 250       22.67  2.00
# 251       17.82  1.75
# 252       18.78  3.00
#
# [253 rows x 2 columns]

# %%
tips_df[['total_bill']]
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# ..          ...
# 248       29.03
# 249       27.18
# 250       22.67
# 251       17.82
# 252       18.78
#
# [253 rows x 1 columns]

# %% [markdown]
# ### Creare coloana calculata

# %%
tips_df['tip_percentage'] = 100 * tips_df['tip'] / tips_df['total_bill']

# %%
tips_df[['total_bill', 'tip', 'tip_percentage']]
# Out:
#      total_bill   tip  tip_percentage
# 0         16.99  1.01        5.944673
# 1         10.34  1.66       16.054159
# 2         21.01  3.50       16.658734
# 3         23.68  3.31       13.978041
# 4         24.59  3.61       14.680765
# ..          ...   ...             ...
# 248       29.03  5.92       20.392697
# 249       27.18  2.00        7.358352
# 250       22.67  2.00        8.822232
# 251       17.82  1.75        9.820426
# 252       18.78  3.00       15.974441
#
# [253 rows x 3 columns]

# %%
tips_df['tip_percentage'] = round(tips_df['tip_percentage'], 2)
tips_df[['total_bill', 'tip', 'tip_percentage']]
# Out:
#      total_bill   tip  tip_percentage
# 0         16.99  1.01            5.94
# 1         10.34  1.66           16.05
# 2         21.01  3.50           16.66
# 3         23.68  3.31           13.98
# 4         24.59  3.61           14.68
# ..          ...   ...             ...
# 248       29.03  5.92           20.39
# 249       27.18  2.00            7.36
# 250       22.67  2.00            8.82
# 251       17.82  1.75            9.82
# 252       18.78  3.00           15.97
#
# [253 rows x 3 columns]

# %% [markdown]
# ### Eliminare coloana

# %%
tips_df.drop(labels = ['CC Number', 'tip_percentage'], axis = 1)    
#tips_df.drop(columns = ['CC Number', 'tip_percentage'])
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 248       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 249       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 250       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 251       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 252       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name Payment ID
# ...

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 248       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 249       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 250       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 251       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 252       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
#Pentru a efectua modificari asupra dataframe-ului original:
tips_df = tips_df.drop(columns = ['CC Number', 'tip_percentage'])
#SAU
#tips_df.drop(columns = ['CC Number', 'tip_percentage'], inplace = True)

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 248       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 249       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 250       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 251       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 252       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name Payment ID
# ...

# %% [markdown]
# ### Indexare

# %%
tips_df.index
# Out:
# RangeIndex(start=0, stop=253, step=1)

# %%
tips_df.set_index(keys = 'Payment ID')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name
# Payment ID
# Sun2959                 8.49  Christy Cunningham
# Sun4608                 3.45      Douglas Tucker
# ...

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 248       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 249       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 250       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 251       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 252       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name Payment ID
# ...

# %%
tips_df = tips_df.set_index(keys = 'Payment ID')

# %%
tips_df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name
# Payment ID
# Sun2959                 8.49  Christy Cunningham
# Sun4608                 3.45      Douglas Tucker
# ...

# %%
tips_df.reset_index()
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 248    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 249    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 250    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 251      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 252    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name
# 0                8.49  Christy Cunningham
# 1                3.45      Douglas Tucker
# ...

# %%
tips_df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name
# Payment ID
# Sun2959                 8.49  Christy Cunningham
# Sun4608                 3.45      Douglas Tucker
# ...

# %%
.iloc - integer based location
.loc - label based location

# %%
tips_df.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# Name: Sun2959, dtype: object

# %%
tips_df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# Name: Sun2959, dtype: object

# %%
tips_df.iloc[0:5]  #tips_df.iloc[:5]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name
# Payment ID
# Sun2959                 8.49  Christy Cunningham
# Sun4608                 3.45      Douglas Tucker
# Sun4458                 7.00      Travis Walters
# Sun5260                11.84    Nathaniel Harris
# Sun2251                 6.15        Tonya Carter

# %%
tips_df.iloc[-5:]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person       Payer Name
# Payment ID
# Sat2657                 9.68    Michael Avila
# Sat1766                13.59   Monica Sanders
# Sat3880                11.34       Keith Wong
# Sat17                   8.91     Dennis Dixon
# Thur672                 9.39  Michelle Hardin

# %%
tips_df.loc['Sun2959':'Sun2251']
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name
# Payment ID
# Sun2959                 8.49  Christy Cunningham
# Sun4608                 3.45      Douglas Tucker
# Sun4458                 7.00      Travis Walters
# Sun5260                11.84    Nathaniel Harris
# Sun2251                 6.15        Tonya Carter

# %%
tips_df.loc[['Sun2959', 'Sun5260']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name
# Payment ID
# Sun2959                 8.49  Christy Cunningham
# Sun5260                11.84    Nathaniel Harris

# %% [markdown]
# #### Eliminare linii

# %%
tips_df.drop(index = 'Sun2959')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name
# Payment ID
# Sun4608                 3.45    Douglas Tucker
# Sun4458                 7.00    Travis Walters
# ...

# %%
tips_df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name
# Payment ID
# Sun2959                 8.49  Christy Cunningham
# Sun4608                 3.45      Douglas Tucker
# ...

# %%
first_row_ser = tips_df.iloc[0]
first_row_ser
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# Name: Sun2959, dtype: object

# %%
tips_df = tips_df.drop(index = 'Sun2959')
tips_df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name
# Payment ID
# Sun4608                 3.45    Douglas Tucker
# Sun4458                 7.00    Travis Walters
# ...

# %% [markdown]
# #### Adaugare linii

# %%
tips_df = tips_df.append(other = first_row_ser)
tips_df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
#
#             price_per_person          Payer Name
# Payment ID
# Sun4608                 3.45      Douglas Tucker
# Sun4458                 7.00      Travis Walters
# ...

# %% [markdown]
# ### Filtrare conditionata

# %%
tips_mask = tips_df['total_bill'] > 30
tips_mask
# Out:
# Payment ID
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
# Sun9679    False
#            ...
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672    False
# Sun2959    False
# Name: total_bill, Length: 253, dtype: bool

# %%
len(tips_df[tips_mask])
# Out:
# 34

# %%
tips_df[~tips_mask] #~ = operator complement; negatie a conditiei de filtrare
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
#
#             price_per_person          Payer Name
# Payment ID
# Sun4608                 3.45      Douglas Tucker
# Sun4458                 7.00      Travis Walters
# ...

# %%
tips_mask = tips_df['total_bill'] > 30
tips_df[tips_mask]

# %%
tips_df[tips_df['total_bill'] > 30]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26   5.00  Female     No   Sun  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat6373          31.27   5.00    Male     No   Sat  Dinner     3
# Sun2274          30.40   5.60    Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sun6165          34.81   5.20  Female     No   Sun  Dinner     4
# Sat8903          38.01   3.00    Male    Yes   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur8801         32.68   5.00    Male    Yes  Thur   Lunch     2
# Thur7972         34.83   5.17  Female     No  Thur   Lunch     4
# Fri9628          40.17   4.73    Male    Yes   Fri  Dinner     4
# Sat6240          44.30   2.50  Female    Yes   Sat  Dinner     3
# Sun591           38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
tips_df.loc[tips_df['total_bill'] > 30]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26   5.00  Female     No   Sun  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat6373          31.27   5.00    Male     No   Sat  Dinner     3
# Sun2274          30.40   5.60    Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sun6165          34.81   5.20  Female     No   Sun  Dinner     4
# Sat8903          38.01   3.00    Male    Yes   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur8801         32.68   5.00    Male    Yes  Thur   Lunch     2
# Thur7972         34.83   5.17  Female     No  Thur   Lunch     4
# Fri9628          40.17   4.73    Male    Yes   Fri  Dinner     4
# Sat6240          44.30   2.50  Female    Yes   Sat  Dinner     3
# Sun591           38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
tips_df.query(expr = "total_bill > 30")
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26   5.00  Female     No   Sun  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat6373          31.27   5.00    Male     No   Sat  Dinner     3
# Sun2274          30.40   5.60    Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sun6165          34.81   5.20  Female     No   Sun  Dinner     4
# Sat8903          38.01   3.00    Male    Yes   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur8801         32.68   5.00    Male    Yes  Thur   Lunch     2
# Thur7972         34.83   5.17  Female     No  Thur   Lunch     4
# Fri9628          40.17   4.73    Male    Yes   Fri  Dinner     4
# Sat6240          44.30   2.50  Female    Yes   Sat  Dinner     3
# Sun591           38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
and or not

# %%
& | ~

# %%
(tips_df['total_bill'] > 30) & (tips_df['sex'] == 'Female')
# Out:
# Payment ID
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
# Sun9679    False
#            ...
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672    False
# Sun2959    False
# Length: 253, dtype: bool

# %%
tips_df[(tips_df['total_bill'] > 30) & (tips_df['sex'] == 'Female')]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26  5.00  Female     No   Sun  Dinner     4
# Sun6165          34.81  5.20  Female     No   Sun  Dinner     4
# Thur7972         34.83  5.17  Female     No  Thur   Lunch     4
# Sat6240          44.30  2.50  Female    Yes   Sat  Dinner     3
# Thur9313         43.11   NaN  Female    Yes  Thur   Lunch     4
# Sat8863          30.14  3.09  Female    Yes   Sat  Dinner     4
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
#
#             price_per_person      Payer Name
# Payment ID
# Sun6686                 8.82    Diane Macias
# Sun6165                 8.70    Emily Daniel
# Thur7972                8.71     Shawna Cook
# Sat6240                14.77   Heather Cohen
# Thur9313               10.78     Brooke Soto
# Sat8863                 7.54    Shelby House
# ...

# %%
tips_df[(tips_df['total_bill'] > 30) & (tips_df['sex'] != 'Male')]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26  5.00  Female     No   Sun  Dinner     4
# Sun6165          34.81  5.20  Female     No   Sun  Dinner     4
# Thur7972         34.83  5.17  Female     No  Thur   Lunch     4
# Sat6240          44.30  2.50  Female    Yes   Sat  Dinner     3
# Thur9313         43.11   NaN  Female    Yes  Thur   Lunch     4
# Sat8863          30.14  3.09  Female    Yes   Sat  Dinner     4
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
#
#             price_per_person      Payer Name
# Payment ID
# Sun6686                 8.82    Diane Macias
# Sun6165                 8.70    Emily Daniel
# Thur7972                8.71     Shawna Cook
# Sat6240                14.77   Heather Cohen
# Thur9313               10.78     Brooke Soto
# Sat8863                 7.54    Shelby House
# ...

# %%
tips_df[(tips_df['total_bill'] > 30) & ~(tips_df['sex'] == 'Male')]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26  5.00  Female     No   Sun  Dinner     4
# Sun6165          34.81  5.20  Female     No   Sun  Dinner     4
# Thur7972         34.83  5.17  Female     No  Thur   Lunch     4
# Sat6240          44.30  2.50  Female    Yes   Sat  Dinner     3
# Thur9313         43.11   NaN  Female    Yes  Thur   Lunch     4
# Sat8863          30.14  3.09  Female    Yes   Sat  Dinner     4
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
#
#             price_per_person      Payer Name
# Payment ID
# Sun6686                 8.82    Diane Macias
# Sun6165                 8.70    Emily Daniel
# Thur7972                8.71     Shawna Cook
# Sat6240                14.77   Heather Cohen
# Thur9313               10.78     Brooke Soto
# Sat8863                 7.54    Shelby House
# ...

# %%
tips_df[(tips_df['day'] == 'Sat') | (tips_df['day'] == 'Sun')]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
#
#             price_per_person          Payer Name
# Payment ID
# Sun4608                 3.45      Douglas Tucker
# Sun4458                 7.00      Travis Walters
# ...

# %%
options = ['Sat', 'Sun']
tips_df['day'].isin(options)
# Out:
# Payment ID
# Sun4608     True
# Sun4458     True
# Sun5260     True
# Sun2251     True
# Sun9679     True
#            ...
# Sat1766     True
# Sat3880     True
# Sat17       True
# Thur672    False
# Sun2959     True
# Name: day, Length: 253, dtype: bool

# %%
tips_df[tips_df['day'].isin(options)]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
#
#             price_per_person          Payer Name
# Payment ID
# Sun4608                 3.45      Douglas Tucker
# Sun4458                 7.00      Travis Walters
# ...

# %%
tips_df[tips_df['day'].isin(['Sat', 'Sun'])][['total_bill', 'tip']] #dataframe[conditii pe linii][lista de coloane]
# Out:
#             total_bill   tip
# Payment ID
# Sun4608          10.34  1.66
# Sun4458          21.01  3.50
# Sun5260          23.68  3.31
# Sun2251          24.59  3.61
# Sun9679          25.29  4.71
# ...                ...   ...
# Sat2657          29.03  5.92
# Sat1766          27.18  2.00
# Sat3880          22.67  2.00
# Sat17            17.82  1.75
# Sun2959          16.99  1.01
#
# [171 rows x 2 columns]

# %%
tips_df.loc[tips_df['day'].isin(['Sat', 'Sun']), ['total_bill', 'tip']] #dataframe.loc[conditii pe linie, lista de coloane]
# Out:
#             total_bill   tip
# Payment ID
# Sun4608          10.34  1.66
# Sun4458          21.01  3.50
# Sun5260          23.68  3.31
# Sun2251          24.59  3.61
# Sun9679          25.29  4.71
# ...                ...   ...
# Sat2657          29.03  5.92
# Sat1766          27.18  2.00
# Sat3880          22.67  2.00
# Sat17            17.82  1.75
# Sun2959          16.99  1.01
#
# [171 rows x 2 columns]

# %%
(tips_df
 .query(expr = "day in ('Sat', 'Sun')")
 [['total_bill', 'tip']]
)

#tips_df\
# .query(expr = "day in ('Sat', 'Sun')")\
# [['total_bill', 'tip']]
# Out:
#             total_bill   tip
# Payment ID
# Sun4608          10.34  1.66
# Sun4458          21.01  3.50
# Sun5260          23.68  3.31
# Sun2251          24.59  3.61
# Sun9679          25.29  4.71
# ...                ...   ...
# Sat2657          29.03  5.92
# Sat1766          27.18  2.00
# Sat3880          22.67  2.00
# Sat17            17.82  1.75
# Sun2959          16.99  1.01
#
# [171 rows x 2 columns]

# %%
(tips_df
 .query(expr = "day in @options") #`CC Number`
 [['total_bill', 'tip']]
)
# Out:
#             total_bill   tip
# Payment ID
# Sun4608          10.34  1.66
# Sun4458          21.01  3.50
# Sun5260          23.68  3.31
# Sun2251          24.59  3.61
# Sun9679          25.29  4.71
# ...                ...   ...
# Sat2657          29.03  5.92
# Sat1766          27.18  2.00
# Sat3880          22.67  2.00
# Sat17            17.82  1.75
# Sun2959          16.99  1.01
#
# [171 rows x 2 columns]

# %% [markdown]
# ## Tema -> pg 69
